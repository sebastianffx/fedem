# %%
import sys

from utils_fedavg import get_optimizer
from weighting_schemes import average_weights, average_weights_beta, average_weights_softmax

import torch
from torch import nn, optim

import monai
import numpy as np
import nibabel as nib
from glob import glob
from matplotlib import pyplot as plt
import copy
from scipy.spatial import distance_matrix
from monai.transforms import (
    Activations,
    AsChannelFirstD,
    AddChannel,
    AsDiscrete,
    Compose,
    LoadImage,
    RandRotate90,
    RandSpatialCrop,
    ScaleIntensity,
    EnsureType,
    Resized
)

from monai.data import (
    ArrayDataset, GridPatchDataset, create_test_image_3d, PatchIter)
from monai.utils import first
from monai.metrics import DiceMetric
from monai.inferers import sliding_window_inference
from monai.data import DataLoader, decollate_batch
from natsort import natsorted
import umap

from torch.utils.tensorboard import SummaryWriter
from sklearn.preprocessing import StandardScaler
import sklearn

# %%
LOCATION = 'scan' #laptop
if LOCATION == 'scan':
    isles_data_root = '/str/data/ASAP/miccai22_data/isles/federated/'
    exp_root = '/home/otarola/miccai22/fedem/'

if LOCATION == 'laptop':
    isles_data_root = '/data/ASAP/miccai22_data/isles/federated/'

# %%
#Hyperparams cell
modality = 'Tmax'
batch_size = 2
num_epochs = 300
learning_rate = 0.000932#lrs[0] #To comment in the loop
weighting_scheme = 'FEDAVG'
beta_val=0.9

# %%
def get_train_valid_test_partitions(modality, isles_data_root, num_centers=4):
    centers_partitions = [[] for i in range(num_centers)]
    for center_num in range(1,num_centers+1):
        center_paths_train  = sorted(glob(isles_data_root+'center'+str(center_num)+'/train'+'/**/*'+modality+'*/*.nii'))
        center_paths_valid  = sorted(glob(isles_data_root+'center'+str(center_num)+'/valid'+'/**/*'+modality+'*/*.nii'))
        center_paths_test   = sorted(glob(isles_data_root+'center'+str(center_num)+'/test'+'/**/*'+modality+'*/*.nii'))
        center_lbl_paths_train  = sorted(glob(isles_data_root+'center'+str(center_num)+'/train'+'/**/*OT*/*nii'))
        center_lbl_paths_valid  = sorted(glob(isles_data_root+'center'+str(center_num)+'/valid'+'/**/*OT*/*nii'))
        center_lbl_paths_test  = sorted(glob(isles_data_root+'center'+str(center_num)+'/test'+'/**/*OT*/*nii'))
        centers_partitions[center_num-1] = [[center_paths_train,center_paths_valid,center_paths_test],[center_lbl_paths_train,center_lbl_paths_valid,center_lbl_paths_test]]
    return centers_partitions

# %%
partitions_paths = get_train_valid_test_partitions(modality, isles_data_root, 4)

# %%
len(partitions_paths[0][0][2]),len(partitions_paths[0][1][2]) #idx_order: center,img_label,partition
# Out:
# (4, 4)

# %%
#creating the dataloader for 10 ISLES volumes using the T_max and the CBF
#For cbf we are windowing 1-1024
#For tmax we'll window 0-60
#For CBV we'll window 0-200
if modality =='CBF':
    max_intensity = 1200
if modality =='CBV':
    max_intensity = 200
if modality =='Tmax' or modality =='MTT':
    max_intensity = 30

# %%
imtrans = Compose(
    [   LoadImage(image_only=True),
        #RandScaleIntensity( factors=0.1, prob=0.5),
        ScaleIntensity(minv=0.0, maxv=max_intensity),
        AddChannel(),
        RandRotate90( prob=0.5, spatial_axes=[0, 1]),
        RandSpatialCrop((224, 224,1), random_size=False),
        EnsureType(),
        #Resized
    ]
)

segtrans = Compose(
    [   LoadImage(image_only=True),
        AddChannel(),
        RandRotate90( prob=0.5, spatial_axes=[0, 1]),
        RandSpatialCrop((224, 224,1), random_size=False),
        EnsureType(),
        #Resized
    ]
)


imtrans_neutral = Compose(
    [   LoadImage(image_only=True),
        #RandScaleIntensity( factors=0.1, prob=0.5),
        ScaleIntensity(minv=0.0, maxv=max_intensity),
        AddChannel(),
        RandSpatialCrop((224, 224,1), random_size=False),
        EnsureType(),
        #Resized
    ]
)

segtrans_neutral = Compose(
    [   LoadImage(image_only=True),
        AddChannel(),
        RandSpatialCrop((224, 224,1), random_size=False),
        EnsureType(),
        #Resized
    ]
)

imtrans_test = Compose(
    [   LoadImage(image_only=True),
        ScaleIntensity(minv=0.0, maxv=max_intensity),
        AddChannel(),
        #RandSpatialCrop((224, 224,1), random_size=False), In test we would like to process ALL slices
        EnsureType(),
        #Resized
    ]
)

segtrans_test = Compose(
    [   LoadImage(image_only=True),
        AddChannel(),
        #RandSpatialCrop((224, 224,1), random_size=False),
        EnsureType(),
        #Resized
    ]
)

# %%
def center_dataloaders(partitions_paths_center, batch_size=2):#
    center_ds_train = ArrayDataset(partitions_paths_center[0][0], imtrans, partitions_paths_center[1][0], segtrans)
    center_train_loader   = torch.utils.data.DataLoader(
        center_ds_train, batch_size=batch_size, num_workers=1, pin_memory=torch.cuda.is_available()
    )

    center_ds_valid = ArrayDataset(partitions_paths_center[0][1], imtrans, partitions_paths_center[1][1], segtrans)
    center_valid_loader   = torch.utils.data.DataLoader(
        center_ds_valid, batch_size=batch_size, num_workers=1, pin_memory=torch.cuda.is_available()
    )

    center_ds_test = ArrayDataset(partitions_paths_center[0][2], imtrans_test, partitions_paths_center[1][2], segtrans_test)
    center_test_loader   = torch.utils.data.DataLoader(
        center_ds_test, batch_size=batch_size, num_workers=1, pin_memory=torch.cuda.is_available()
    )
    return center_train_loader, center_valid_loader, center_test_loader

# %%
centers_data_loaders = []
for i in range(len(partitions_paths)):#Adding all the centers data loaders
    centers_data_loaders.append(center_dataloaders(partitions_paths[i],batch_size))

# %%
len(centers_data_loaders)
# Out:
# 4

# %%
partitions_test_imgs = [partitions_paths[i][0][2] for i in range(len(partitions_paths))]
partitions_test_lbls = [partitions_paths[i][1][2] for i in range(len(partitions_paths))]

partitions_valid_imgs = [partitions_paths[i][0][1] for i in range(len(partitions_paths))]
partitions_valid_lbls = [partitions_paths[i][1][1] for i in range(len(partitions_paths))]

#For selecting the model and testing in the heldout partition we collect the valid and test data from ALL centers
all_ds_test = ArrayDataset([i for l in partitions_test_imgs for i in l],
                            imtrans, [i for l in partitions_test_lbls for i in l],
                            segtrans)
all_test_loader   = torch.utils.data.DataLoader(
    all_ds_test, batch_size=1, num_workers=1, pin_memory=torch.cuda.is_available()
)


all_ds_valid = ArrayDataset([i for l in partitions_valid_imgs for i in l],
                            imtrans, [i for l in partitions_valid_lbls for i in l],
                            segtrans)
all_valid_loader   = torch.utils.data.DataLoader(
    all_ds_valid, batch_size=1, num_workers=1, pin_memory=torch.cuda.is_available()
)

# %%
trainloaders_lengths = [len(centers_data_loaders[i][0].dataset) for i in [0,1,3]] #We don't take the Siemens training case

beta = 0.9

weight_classes = [(1-beta)/(1-np.power(beta,length)) for length in trainloaders_lengths]
print(trainloaders_lengths)
print(weight_classes)
# Out:
# [15, 41, 9]
# [0.1259273180814282, 0.10134821448516575, 0.16324411477092318]

# %%
dice_metric = DiceMetric(include_background=False, reduction="mean", get_not_nans=False)
post_trans = Compose([EnsureType(), Activations(sigmoid=True), AsDiscrete(threshold=0.5)])
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)

global_model = monai.networks.nets.UNet(
        spatial_dims=2,
        in_channels=1,
        out_channels=1,
        channels=(16, 32, 64, 128),
        strides=(2, 2, 2),
        kernel_size = (3,3),
        #dropout = 0.2,
        num_res_units=2,
).to(device)

loss_function = monai.losses.DiceLoss(sigmoid=True)
optimizer = torch.optim.Adam(global_model.parameters(), lr=learning_rate)



val_interval = 2
best_metric = -1
best_metric_epoch = -1
epoch_loss_values = list()
metric_values = list()
writer = SummaryWriter(comment=modality+"_"+weighting_scheme+"_LR_"+str(learning_rate)+"_BATCH_"+str(batch_size))


batch_data = next(iter(centers_data_loaders[0][0]))
# Out:
# cuda

# %%
inputs, labels = batch_data[0][:,:,:,:,0].to(device),batch_data[1][:,:,:,:,0].to(device)
#torch.swapaxes(batch_data[0][0], 1, -1).to(device), torch.swapaxes(batch_data[1][0], 1, -1).to(device).to(device)
print(inputs.shape,labels.shape)


global_model.train()

# copy weights
global_weights = global_model.state_dict()

#Testing that the model works in one iteration
optimizer.zero_grad()
outputs = global_model(inputs)
loss    = loss_function(outputs, labels)
loss.backward()
optimizer.step()
# Out:
# torch.Size([2, 1, 224, 224]) torch.Size([2, 1, 224, 224])

# %%
global_model.train()
epoch_loss = 0
train_loss, train_dice = [], []

# %%
def perform_one_local_epoch(train_loader, local_model, local_optimizer, loss_function, client_idx=0):
    batch_loss_client = []
    for batch_data in train_loader:
        inputs, labels = batch_data[0][:,:,:,:,0].to(device), batch_data[1][:,:,:,:,0].to(device)
        local_model.zero_grad()        
        outputs = local_model(inputs)
        loss = loss_function(outputs, labels)
        loss.backward()
        local_optimizer.step()
        batch_loss_client.append(loss.item())
    avg_loss_client = copy.deepcopy(sum(batch_loss_client) / len(batch_loss_client))
    print("Loss for client: " +str(client_idx)+" :" +str(avg_loss_client))
    return avg_loss_client

# %%
for epoch in range(num_epochs):
    print("-" * 10)
    print(f"local epoch {epoch + 1}/{num_epochs}")

    local_weights, local_losses = [], []
    global_model.train()

    global_weights = global_model.state_dict()
    modelc1, modelc2, modelc4 = copy.deepcopy(global_model), copy.deepcopy(global_model), copy.deepcopy(global_model)
    optimizerc1 = torch.optim.Adam(modelc1.parameters(), learning_rate)
    optimizerc2 = torch.optim.Adam(modelc2.parameters(), learning_rate)
    optimizerc4 = torch.optim.Adam(modelc4.parameters(), learning_rate)

    modelc1.train()
    modelc2.train()
    modelc4.train()

    print(f"local epoch for train_loader 1: {epoch + 1}/{num_epochs}")
    loss_c1 = perform_one_local_epoch(centers_data_loaders[0][0], modelc1, optimizerc1, loss_function, client_idx=1)
    local_losses.append(loss_c1)
    print("Loss C1: " + str(local_losses[-1]))

    print(f"local epoch for train_loader 2: {epoch + 1}/{num_epochs}")
    loss_c2 = perform_one_local_epoch(centers_data_loaders[1][0], modelc2, optimizerc2, loss_function, client_idx=2)
    local_losses.append(loss_c2)
    print("Loss C2: " + str(local_losses[-1]))

    #C3 is the Siemens data loader for which we have only one data point
    print(f"local epoch for train_loader 4: {epoch + 1}/{num_epochs}")
    loss_c4 = perform_one_local_epoch(centers_data_loaders[3][0], modelc4, optimizerc4, loss_function, client_idx=4)
    local_losses.append(loss_c4)
    print("Loss C4: " + str(local_losses[-1]))

    loss_avg = sum(local_losses) / len(local_losses)
    train_loss.append(loss_avg)


    print(f"train_loss: {train_loss[-1]:.4f}")
    writer.add_scalar("train_loss", loss_avg, epoch)

    #Agregating the weights with the selected weighting scheme
    if weighting_scheme =='FEDAVG':
        global_weights = average_weights([copy.deepcopy(modelc1.state_dict()),copy.deepcopy(modelc2.state_dict()),copy.deepcopy(modelc4.state_dict())])
    if weighting_scheme =='BETA':
        global_weights = average_weights_beta([copy.deepcopy(modelc1.state_dict()),copy.deepcopy(modelc2.state_dict()),copy.deepcopy(modelc4.state_dict())],trainloaders_lengths,beta_val)
    if weighting_scheme =='SOFTMAX':
        global_weights = average_weights_softmax([copy.deepcopy(modelc1.state_dict()),copy.deepcopy(modelc2.state_dict()),copy.deepcopy(modelc4.state_dict())],trainloaders_lengths)

    
    # Update global weights with the averaged model weights.
    global_model.load_state_dict(global_weights)

    if (epoch + 1) % val_interval == 0:
        global_model.eval()
        with torch.no_grad():
            val_images = None
            val_labels = None
            val_outputs = None
            for val_data in all_valid_loader:
                val_images, val_labels = val_data[0].to(device), val_data[1].to(device)
                val_outputs = global_model(val_images[:,:,:,:,0])
                val_outputs = val_outputs>0.5 #This assumes one slice in the last dim
                dice_metric(y_pred=val_outputs, y=val_labels[:,:,:,:,0])
            # aggregate the final mean dice result
            metric = dice_metric.aggregate().item()
            # reset the status for next validation round
            dice_metric.reset()
            metric_values.append(metric)
            if metric > best_metric:
                best_metric = metric
                best_metric_epoch = epoch + 1
                torch.save(global_model.state_dict(), modality+'_beta_'+str(beta)+'_'+weighting_scheme+'_best_metric_model_segmentation2d_array.pth')
                print("saved new best metric model")
            print(
                "current epoch: {} current mean dice: {:.4f} best mean dice: {:.4f} at epoch {}".format(
                    epoch + 1, metric, best_metric, best_metric_epoch
                )
            )
            writer.add_scalar("val_mean_dice", metric, epoch + 1)
# Out:
# ----------
# local epoch 1/300
# local epoch for train_loader 1: 1/300
# Loss for client: 1 :0.9819399565458298
# Loss C1: 0.9819399565458298
# local epoch for train_loader 2: 1/300
# Loss for client: 2 :0.9443082894597735
# Loss C2: 0.9443082894597735
# local epoch for train_loader 4: 1/300
# Loss for client: 4 :0.9876788020133972
# Loss C4: 0.9876788020133972
# train_loss: 0.9713
# ----------
# local epoch 2/300
# local epoch for train_loader 1: 2/300
# Loss for client: 1 :0.975497879087925
# Loss C1: 0.975497879087925
# local epoch for train_loader 2: 2/300
# Loss for client: 2 :0.9328742594945998
# Loss C2: 0.9328742594945998
# local epoch for train_loader 4: 2/300
# Loss for client: 4 :0.9819965481758117
# Loss C4: 0.9819965481758117
# train_loss: 0.9635
# saved new best metric model
# current epoch: 2 current mean dice: 0.3677 best mean dice: 0.3677 at epoch 2
# ----------
# local epoch 3/300
# local epoch for train_loader 1: 3/300
# Loss for client: 1 :0.9712964072823524
# Loss C1: 0.9712964072823524
# local epoch for train_loader 2: 3/300
# Loss for client: 2 :0.925442636013031
# Loss C2: 0.925442636013031
# local epoch for train_loader 4: 3/300
# Loss for client: 4 :0.9783115983009338
# Loss C4: 0.9783115983009338
# train_loss: 0.9584
# ----------
# local epoch 4/300
# local epoch for train_loader 1: 4/300
# Loss for client: 1 :0.9697467386722565
# Loss C1: 0.9697467386722565
# local epoch for train_loader 2: 4/300
# Loss for client: 2 :0.9227806471642994
# Loss C2: 0.9227806471642994
# local epoch for train_loader 4: 4/300
# Loss for client: 4 :0.9765893459320069
# Loss C4: 0.9765893459320069
# train_loss: 0.9564
# saved new best metric model
# current epoch: 4 current mean dice: 0.4237 best mean dice: 0.4237 at epoch 4
# ----------
# local epoch 5/300
# local epoch for train_loader 1: 5/300
# Loss for client: 1 :0.968813419342041
# Loss C1: 0.968813419342041
# local epoch for train_loader 2: 5/300
# Loss for client: 2 :0.9213856004533314
# Loss C2: 0.9213856004533314
# local epoch for train_loader 4: 5/300
# Loss for client: 4 :0.9756915688514709
# Loss C4: 0.9756915688514709
# train_loss: 0.9553
# ----------
# local epoch 6/300
# local epoch for train_loader 1: 6/300
# Loss for client: 1 :0.9679589867591858
# Loss C1: 0.9679589867591858
# local epoch for train_loader 2: 6/300
# Loss for client: 2 :0.9198320280937922
# Loss C2: 0.9198320280937922
# local epoch for train_loader 4: 6/300
# Loss for client: 4 :0.9753522634506225
# Loss C4: 0.9753522634506225
# train_loss: 0.9544
# saved new best metric model
# current epoch: 6 current mean dice: 0.4546 best mean dice: 0.4546 at epoch 6
# ----------
# local epoch 7/300
# local epoch for train_loader 1: 7/300
# Loss for client: 1 :0.9673941433429718
# Loss C1: 0.9673941433429718
# local epoch for train_loader 2: 7/300
# Loss for client: 2 :0.9185048852648053
# Loss C2: 0.9185048852648053
# local epoch for train_loader 4: 7/300
# Loss for client: 4 :0.9757990360260009
# Loss C4: 0.9757990360260009
# train_loss: 0.9539
# ----------
# local epoch 8/300
# local epoch for train_loader 1: 8/300
# Loss for client: 1 :0.9669888988137245
# Loss C1: 0.9669888988137245
# local epoch for train_loader 2: 8/300
# Loss for client: 2 :0.9175033058438983
# Loss C2: 0.9175033058438983
# local epoch for train_loader 4: 8/300
# Loss for client: 4 :0.9757131099700928
# Loss C4: 0.9757131099700928
# train_loss: 0.9534
# current epoch: 8 current mean dice: 0.4349 best mean dice: 0.4546 at epoch 6
# ----------
# local epoch 9/300
# local epoch for train_loader 1: 9/300
# Loss for client: 1 :0.9668978080153465
# Loss C1: 0.9668978080153465
# local epoch for train_loader 2: 9/300
# Loss for client: 2 :0.9162841666312445
# Loss C2: 0.9162841666312445
# local epoch for train_loader 4: 9/300
# Loss for client: 4 :0.9741976618766784
# Loss C4: 0.9741976618766784
# train_loss: 0.9525
# ----------
# local epoch 10/300
# local epoch for train_loader 1: 10/300
# Loss for client: 1 :0.9657500982284546
# Loss C1: 0.9657500982284546
# local epoch for train_loader 2: 10/300
# Loss for client: 2 :0.9153988730339777
# Loss C2: 0.9153988730339777
# local epoch for train_loader 4: 10/300
# Loss for client: 4 :0.9740590691566468
# Loss C4: 0.9740590691566468
# train_loss: 0.9517
# saved new best metric model
# current epoch: 10 current mean dice: 0.4547 best mean dice: 0.4547 at epoch 10
# ----------
# local epoch 11/300
# local epoch for train_loader 1: 11/300
# Loss for client: 1 :0.9651319086551666
# Loss C1: 0.9651319086551666
# local epoch for train_loader 2: 11/300
# Loss for client: 2 :0.9143678375652858
# Loss C2: 0.9143678375652858
# local epoch for train_loader 4: 11/300
# Loss for client: 4 :0.973642635345459
# Loss C4: 0.973642635345459
# train_loss: 0.9510
# ----------
# local epoch 12/300
# local epoch for train_loader 1: 12/300
# Loss for client: 1 :0.9648811295628548
# Loss C1: 0.9648811295628548
# local epoch for train_loader 2: 12/300
# Loss for client: 2 :0.9132345375560579
# Loss C2: 0.9132345375560579
# local epoch for train_loader 4: 12/300
# Loss for client: 4 :0.9739168643951416
# Loss C4: 0.9739168643951416
# train_loss: 0.9507
# saved new best metric model
# current epoch: 12 current mean dice: 0.4674 best mean dice: 0.4674 at epoch 12
# ----------
# local epoch 13/300
# local epoch for train_loader 1: 13/300
# Loss for client: 1 :0.9643079191446304
# Loss C1: 0.9643079191446304
# local epoch for train_loader 2: 13/300
# Loss for client: 2 :0.9126745604333424
# Loss C2: 0.9126745604333424
# local epoch for train_loader 4: 13/300
# Loss for client: 4 :0.9730445981025696
# Loss C4: 0.9730445981025696
# train_loss: 0.9500
# ----------
# local epoch 14/300
# local epoch for train_loader 1: 14/300
# Loss for client: 1 :0.9636818692088127
# Loss C1: 0.9636818692088127
# local epoch for train_loader 2: 14/300
# Loss for client: 2 :0.9112464955874852
# Loss C2: 0.9112464955874852
# local epoch for train_loader 4: 14/300
# Loss for client: 4 :0.9725567817687988
# Loss C4: 0.9725567817687988
# train_loss: 0.9492
# saved new best metric model
# current epoch: 14 current mean dice: 0.4715 best mean dice: 0.4715 at epoch 14
# ----------
# local epoch 15/300
# local epoch for train_loader 1: 15/300
# Loss for client: 1 :0.9634838178753853
# Loss C1: 0.9634838178753853
# local epoch for train_loader 2: 15/300
# Loss for client: 2 :0.9101353202547345
# Loss C2: 0.9101353202547345
# local epoch for train_loader 4: 15/300
# Loss for client: 4 :0.9722160577774048
# Loss C4: 0.9722160577774048
# train_loss: 0.9486
# ----------
# local epoch 16/300
# local epoch for train_loader 1: 16/300
# Loss for client: 1 :0.9630953222513199
# Loss C1: 0.9630953222513199
# local epoch for train_loader 2: 16/300
# Loss for client: 2 :0.9100174648421151
# Loss C2: 0.9100174648421151
# local epoch for train_loader 4: 16/300
# Loss for client: 4 :0.9716100335121155
# Loss C4: 0.9716100335121155
# train_loss: 0.9482
# current epoch: 16 current mean dice: 0.4655 best mean dice: 0.4715 at epoch 14
# ----------
# local epoch 17/300
# local epoch for train_loader 1: 17/300
# Loss for client: 1 :0.9625045731663704
# Loss C1: 0.9625045731663704
# local epoch for train_loader 2: 17/300
# Loss for client: 2 :0.9090639097349984
# Loss C2: 0.9090639097349984
# local epoch for train_loader 4: 17/300
# Loss for client: 4 :0.9716833114624024
# Loss C4: 0.9716833114624024
# train_loss: 0.9478
# ----------
# local epoch 18/300
# local epoch for train_loader 1: 18/300
# Loss for client: 1 :0.9628109559416771
# Loss C1: 0.9628109559416771
# local epoch for train_loader 2: 18/300
# Loss for client: 2 :0.9070914529618763
# Loss C2: 0.9070914529618763
# local epoch for train_loader 4: 18/300
# Loss for client: 4 :0.9709152936935425
# Loss C4: 0.9709152936935425
# train_loss: 0.9469
# current epoch: 18 current mean dice: 0.4679 best mean dice: 0.4715 at epoch 14
# ----------
# local epoch 19/300
# local epoch for train_loader 1: 19/300
# Loss for client: 1 :0.9617598578333855
# Loss C1: 0.9617598578333855
# local epoch for train_loader 2: 19/300
# Loss for client: 2 :0.9064001809983027
# Loss C2: 0.9064001809983027
# local epoch for train_loader 4: 19/300
# Loss for client: 4 :0.9708798050880432
# Loss C4: 0.9708798050880432
# train_loss: 0.9463
# ----------
# local epoch 20/300
# local epoch for train_loader 1: 20/300
# Loss for client: 1 :0.9615979492664337
# Loss C1: 0.9615979492664337
# local epoch for train_loader 2: 20/300
# Loss for client: 2 :0.9052604493640718
# Loss C2: 0.9052604493640718
# local epoch for train_loader 4: 20/300
# Loss for client: 4 :0.970210611820221
# Loss C4: 0.970210611820221
# train_loss: 0.9457
# current epoch: 20 current mean dice: 0.4710 best mean dice: 0.4715 at epoch 14
# ----------
# local epoch 21/300
# local epoch for train_loader 1: 21/300
# Loss for client: 1 :0.9608909636735916
# Loss C1: 0.9608909636735916
# local epoch for train_loader 2: 21/300
# Loss for client: 2 :0.9040542131378537
# Loss C2: 0.9040542131378537
# local epoch for train_loader 4: 21/300
# Loss for client: 4 :0.9698583722114563
# Loss C4: 0.9698583722114563
# train_loss: 0.9449
# ----------
# local epoch 22/300
# local epoch for train_loader 1: 22/300
# Loss for client: 1 :0.9606833234429359
# Loss C1: 0.9606833234429359
# local epoch for train_loader 2: 22/300
# Loss for client: 2 :0.9032550227074396
# Loss C2: 0.9032550227074396
# local epoch for train_loader 4: 22/300
# Loss for client: 4 :0.9694042325019836
# Loss C4: 0.9694042325019836
# train_loss: 0.9444
# current epoch: 22 current mean dice: 0.4684 best mean dice: 0.4715 at epoch 14
# ----------
# local epoch 23/300
# local epoch for train_loader 1: 23/300
# Loss for client: 1 :0.960291288793087
# Loss C1: 0.960291288793087
# local epoch for train_loader 2: 23/300
# Loss for client: 2 :0.9005788621448335
# Loss C2: 0.9005788621448335
# local epoch for train_loader 4: 23/300
# Loss for client: 4 :0.9689652681350708
# Loss C4: 0.9689652681350708
# train_loss: 0.9433
# ----------
# local epoch 24/300
# local epoch for train_loader 1: 24/300
# Loss for client: 1 :0.9599744603037834
# Loss C1: 0.9599744603037834
# local epoch for train_loader 2: 24/300
# Loss for client: 2 :0.899889968690418
# Loss C2: 0.899889968690418
# local epoch for train_loader 4: 24/300
# Loss for client: 4 :0.9689785718917847
# Loss C4: 0.9689785718917847
# train_loss: 0.9429
# current epoch: 24 current mean dice: 0.4613 best mean dice: 0.4715 at epoch 14
# ----------
# local epoch 25/300
# local epoch for train_loader 1: 25/300
# Loss for client: 1 :0.9593099653720856
# Loss C1: 0.9593099653720856
# local epoch for train_loader 2: 25/300
# Loss for client: 2 :0.8982224861780802
# Loss C2: 0.8982224861780802
# local epoch for train_loader 4: 25/300
# Loss for client: 4 :0.9688175082206726
# Loss C4: 0.9688175082206726
# train_loss: 0.9421
# ----------
# local epoch 26/300
# local epoch for train_loader 1: 26/300
# Loss for client: 1 :0.9587604701519012
# Loss C1: 0.9587604701519012
# local epoch for train_loader 2: 26/300
# Loss for client: 2 :0.897421970253899
# Loss C2: 0.897421970253899
# local epoch for train_loader 4: 26/300
# Loss for client: 4 :0.967927360534668
# Loss C4: 0.967927360534668
# train_loss: 0.9414
# saved new best metric model
# current epoch: 26 current mean dice: 0.4862 best mean dice: 0.4862 at epoch 26
# ----------
# local epoch 27/300
# local epoch for train_loader 1: 27/300
# Loss for client: 1 :0.9583294615149498
# Loss C1: 0.9583294615149498
# local epoch for train_loader 2: 27/300
# Loss for client: 2 :0.8958066276141575
# Loss C2: 0.8958066276141575
# local epoch for train_loader 4: 27/300
# Loss for client: 4 :0.9674407482147217
# Loss C4: 0.9674407482147217
# train_loss: 0.9405
# ----------
# local epoch 28/300
# local epoch for train_loader 1: 28/300
# Loss for client: 1 :0.9577821120619774
# Loss C1: 0.9577821120619774
# local epoch for train_loader 2: 28/300
# Loss for client: 2 :0.8939104534330822
# Loss C2: 0.8939104534330822
# local epoch for train_loader 4: 28/300
# Loss for client: 4 :0.9674206018447876
# Loss C4: 0.9674206018447876
# train_loss: 0.9397
# current epoch: 28 current mean dice: 0.4759 best mean dice: 0.4862 at epoch 26
# ----------
# local epoch 29/300
# local epoch for train_loader 1: 29/300
# Loss for client: 1 :0.9572643339633942
# Loss C1: 0.9572643339633942
# local epoch for train_loader 2: 29/300
# Loss for client: 2 :0.8930095405805678
# Loss C2: 0.8930095405805678
# local epoch for train_loader 4: 29/300
# Loss for client: 4 :0.9668581128120423
# Loss C4: 0.9668581128120423
# train_loss: 0.9390
# ----------
# local epoch 30/300
# local epoch for train_loader 1: 30/300
# Loss for client: 1 :0.9567494988441467
# Loss C1: 0.9567494988441467
# local epoch for train_loader 2: 30/300
# Loss for client: 2 :0.8913602431615194
# Loss C2: 0.8913602431615194
# local epoch for train_loader 4: 30/300
# Loss for client: 4 :0.9663797378540039
# Loss C4: 0.9663797378540039
# train_loss: 0.9382
# saved new best metric model
# current epoch: 30 current mean dice: 0.4954 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 31/300
# local epoch for train_loader 1: 31/300
# Loss for client: 1 :0.956194207072258
# Loss C1: 0.956194207072258
# local epoch for train_loader 2: 31/300
# Loss for client: 2 :0.889922783488319
# Loss C2: 0.889922783488319
# local epoch for train_loader 4: 31/300
# Loss for client: 4 :0.9659176349639893
# Loss C4: 0.9659176349639893
# train_loss: 0.9373
# ----------
# local epoch 32/300
# local epoch for train_loader 1: 32/300
# Loss for client: 1 :0.9557748585939407
# Loss C1: 0.9557748585939407
# local epoch for train_loader 2: 32/300
# Loss for client: 2 :0.8882440129915873
# Loss C2: 0.8882440129915873
# local epoch for train_loader 4: 32/300
# Loss for client: 4 :0.9652666091918946
# Loss C4: 0.9652666091918946
# train_loss: 0.9364
# current epoch: 32 current mean dice: 0.4775 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 33/300
# local epoch for train_loader 1: 33/300
# Loss for client: 1 :0.9548901319503784
# Loss C1: 0.9548901319503784
# local epoch for train_loader 2: 33/300
# Loss for client: 2 :0.8865015847342355
# Loss C2: 0.8865015847342355
# local epoch for train_loader 4: 33/300
# Loss for client: 4 :0.9648634552955627
# Loss C4: 0.9648634552955627
# train_loss: 0.9354
# ----------
# local epoch 34/300
# local epoch for train_loader 1: 34/300
# Loss for client: 1 :0.9542433470487595
# Loss C1: 0.9542433470487595
# local epoch for train_loader 2: 34/300
# Loss for client: 2 :0.8881452282269796
# Loss C2: 0.8881452282269796
# local epoch for train_loader 4: 34/300
# Loss for client: 4 :0.9643864631652832
# Loss C4: 0.9643864631652832
# train_loss: 0.9356
# current epoch: 34 current mean dice: 0.4536 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 35/300
# local epoch for train_loader 1: 35/300
# Loss for client: 1 :0.9536416530609131
# Loss C1: 0.9536416530609131
# local epoch for train_loader 2: 35/300
# Loss for client: 2 :0.8832810464359465
# Loss C2: 0.8832810464359465
# local epoch for train_loader 4: 35/300
# Loss for client: 4 :0.9638482332229614
# Loss C4: 0.9638482332229614
# train_loss: 0.9336
# ----------
# local epoch 36/300
# local epoch for train_loader 1: 36/300
# Loss for client: 1 :0.9530155286192894
# Loss C1: 0.9530155286192894
# local epoch for train_loader 2: 36/300
# Loss for client: 2 :0.8828779317083812
# Loss C2: 0.8828779317083812
# local epoch for train_loader 4: 36/300
# Loss for client: 4 :0.963397228717804
# Loss C4: 0.963397228717804
# train_loss: 0.9331
# current epoch: 36 current mean dice: 0.4626 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 37/300
# local epoch for train_loader 1: 37/300
# Loss for client: 1 :0.9522296190261841
# Loss C1: 0.9522296190261841
# local epoch for train_loader 2: 37/300
# Loss for client: 2 :0.8800524473190308
# Loss C2: 0.8800524473190308
# local epoch for train_loader 4: 37/300
# Loss for client: 4 :0.962792158126831
# Loss C4: 0.962792158126831
# train_loss: 0.9317
# ----------
# local epoch 38/300
# local epoch for train_loader 1: 38/300
# Loss for client: 1 :0.9515264704823494
# Loss C1: 0.9515264704823494
# local epoch for train_loader 2: 38/300
# Loss for client: 2 :0.8779434334664118
# Loss C2: 0.8779434334664118
# local epoch for train_loader 4: 38/300
# Loss for client: 4 :0.962240743637085
# Loss C4: 0.962240743637085
# train_loss: 0.9306
# current epoch: 38 current mean dice: 0.4680 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 39/300
# local epoch for train_loader 1: 39/300
# Loss for client: 1 :0.9507907032966614
# Loss C1: 0.9507907032966614
# local epoch for train_loader 2: 39/300
# Loss for client: 2 :0.8758001157215664
# Loss C2: 0.8758001157215664
# local epoch for train_loader 4: 39/300
# Loss for client: 4 :0.9618214845657349
# Loss C4: 0.9618214845657349
# train_loss: 0.9295
# ----------
# local epoch 40/300
# local epoch for train_loader 1: 40/300
# Loss for client: 1 :0.9500479847192764
# Loss C1: 0.9500479847192764
# local epoch for train_loader 2: 40/300
# Loss for client: 2 :0.8752827303750175
# Loss C2: 0.8752827303750175
# local epoch for train_loader 4: 40/300
# Loss for client: 4 :0.9611443281173706
# Loss C4: 0.9611443281173706
# train_loss: 0.9288
# current epoch: 40 current mean dice: 0.4683 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 41/300
# local epoch for train_loader 1: 41/300
# Loss for client: 1 :0.949265867471695
# Loss C1: 0.949265867471695
# local epoch for train_loader 2: 41/300
# Loss for client: 2 :0.8724982766878038
# Loss C2: 0.8724982766878038
# local epoch for train_loader 4: 41/300
# Loss for client: 4 :0.9605247735977173
# Loss C4: 0.9605247735977173
# train_loss: 0.9274
# ----------
# local epoch 42/300
# local epoch for train_loader 1: 42/300
# Loss for client: 1 :0.9484355375170708
# Loss C1: 0.9484355375170708
# local epoch for train_loader 2: 42/300
# Loss for client: 2 :0.8701164694059462
# Loss C2: 0.8701164694059462
# local epoch for train_loader 4: 42/300
# Loss for client: 4 :0.9599639654159546
# Loss C4: 0.9599639654159546
# train_loss: 0.9262
# current epoch: 42 current mean dice: 0.4668 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 43/300
# local epoch for train_loader 1: 43/300
# Loss for client: 1 :0.9475731924176216
# Loss C1: 0.9475731924176216
# local epoch for train_loader 2: 43/300
# Loss for client: 2 :0.8686673385756356
# Loss C2: 0.8686673385756356
# local epoch for train_loader 4: 43/300
# Loss for client: 4 :0.9592228651046752
# Loss C4: 0.9592228651046752
# train_loss: 0.9252
# ----------
# local epoch 44/300
# local epoch for train_loader 1: 44/300
# Loss for client: 1 :0.9468648135662079
# Loss C1: 0.9468648135662079
# local epoch for train_loader 2: 44/300
# Loss for client: 2 :0.8657965404646737
# Loss C2: 0.8657965404646737
# local epoch for train_loader 4: 44/300
# Loss for client: 4 :0.9586221933364868
# Loss C4: 0.9586221933364868
# train_loss: 0.9238
# current epoch: 44 current mean dice: 0.4805 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 45/300
# local epoch for train_loader 1: 45/300
# Loss for client: 1 :0.9463818594813347
# Loss C1: 0.9463818594813347
# local epoch for train_loader 2: 45/300
# Loss for client: 2 :0.8649109488441831
# Loss C2: 0.8649109488441831
# local epoch for train_loader 4: 45/300
# Loss for client: 4 :0.9579648971557617
# Loss C4: 0.9579648971557617
# train_loss: 0.9231
# ----------
# local epoch 46/300
# local epoch for train_loader 1: 46/300
# Loss for client: 1 :0.9449800550937653
# Loss C1: 0.9449800550937653
# local epoch for train_loader 2: 46/300
# Loss for client: 2 :0.8625216171855018
# Loss C2: 0.8625216171855018
# local epoch for train_loader 4: 46/300
# Loss for client: 4 :0.9573610067367554
# Loss C4: 0.9573610067367554
# train_loss: 0.9216
# current epoch: 46 current mean dice: 0.4871 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 47/300
# local epoch for train_loader 1: 47/300
# Loss for client: 1 :0.9440456330776215
# Loss C1: 0.9440456330776215
# local epoch for train_loader 2: 47/300
# Loss for client: 2 :0.8595152312800998
# Loss C2: 0.8595152312800998
# local epoch for train_loader 4: 47/300
# Loss for client: 4 :0.9567284345626831
# Loss C4: 0.9567284345626831
# train_loss: 0.9201
# ----------
# local epoch 48/300
# local epoch for train_loader 1: 48/300
# Loss for client: 1 :0.9429971352219582
# Loss C1: 0.9429971352219582
# local epoch for train_loader 2: 48/300
# Loss for client: 2 :0.8575066242899213
# Loss C2: 0.8575066242899213
# local epoch for train_loader 4: 48/300
# Loss for client: 4 :0.9559322595596313
# Loss C4: 0.9559322595596313
# train_loss: 0.9188
# current epoch: 48 current mean dice: 0.4738 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 49/300
# local epoch for train_loader 1: 49/300
# Loss for client: 1 :0.9421465769410133
# Loss C1: 0.9421465769410133
# local epoch for train_loader 2: 49/300
# Loss for client: 2 :0.8555440874326796
# Loss C2: 0.8555440874326796
# local epoch for train_loader 4: 49/300
# Loss for client: 4 :0.9551604151725769
# Loss C4: 0.9551604151725769
# train_loss: 0.9176
# ----------
# local epoch 50/300
# local epoch for train_loader 1: 50/300
# Loss for client: 1 :0.9410171136260033
# Loss C1: 0.9410171136260033
# local epoch for train_loader 2: 50/300
# Loss for client: 2 :0.853235791126887
# Loss C2: 0.853235791126887
# local epoch for train_loader 4: 50/300
# Loss for client: 4 :0.9543419599533081
# Loss C4: 0.9543419599533081
# train_loss: 0.9162
# current epoch: 50 current mean dice: 0.4621 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 51/300
# local epoch for train_loader 1: 51/300
# Loss for client: 1 :0.9399953633546829
# Loss C1: 0.9399953633546829
# local epoch for train_loader 2: 51/300
# Loss for client: 2 :0.8499961225759416
# Loss C2: 0.8499961225759416
# local epoch for train_loader 4: 51/300
# Loss for client: 4 :0.9537366986274719
# Loss C4: 0.9537366986274719
# train_loss: 0.9146
# ----------
# local epoch 52/300
# local epoch for train_loader 1: 52/300
# Loss for client: 1 :0.9389554634690285
# Loss C1: 0.9389554634690285
# local epoch for train_loader 2: 52/300
# Loss for client: 2 :0.8475275635719299
# Loss C2: 0.8475275635719299
# local epoch for train_loader 4: 52/300
# Loss for client: 4 :0.952807891368866
# Loss C4: 0.952807891368866
# train_loss: 0.9131
# current epoch: 52 current mean dice: 0.4809 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 53/300
# local epoch for train_loader 1: 53/300
# Loss for client: 1 :0.9378899857401848
# Loss C1: 0.9378899857401848
# local epoch for train_loader 2: 53/300
# Loss for client: 2 :0.8447247445583344
# Loss C2: 0.8447247445583344
# local epoch for train_loader 4: 53/300
# Loss for client: 4 :0.9520063519477844
# Loss C4: 0.9520063519477844
# train_loss: 0.9115
# ----------
# local epoch 54/300
# local epoch for train_loader 1: 54/300
# Loss for client: 1 :0.9367293640971184
# Loss C1: 0.9367293640971184
# local epoch for train_loader 2: 54/300
# Loss for client: 2 :0.8427089665617261
# Loss C2: 0.8427089665617261
# local epoch for train_loader 4: 54/300
# Loss for client: 4 :0.9511975169181823
# Loss C4: 0.9511975169181823
# train_loss: 0.9102
# current epoch: 54 current mean dice: 0.4776 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 55/300
# local epoch for train_loader 1: 55/300
# Loss for client: 1 :0.9357681646943092
# Loss C1: 0.9357681646943092
# local epoch for train_loader 2: 55/300
# Loss for client: 2 :0.8402226184095655
# Loss C2: 0.8402226184095655
# local epoch for train_loader 4: 55/300
# Loss for client: 4 :0.9503811001777649
# Loss C4: 0.9503811001777649
# train_loss: 0.9088
# ----------
# local epoch 56/300
# local epoch for train_loader 1: 56/300
# Loss for client: 1 :0.9344503805041313
# Loss C1: 0.9344503805041313
# local epoch for train_loader 2: 56/300
# Loss for client: 2 :0.8377347574347541
# Loss C2: 0.8377347574347541
# local epoch for train_loader 4: 56/300
# Loss for client: 4 :0.9494442820549012
# Loss C4: 0.9494442820549012
# train_loss: 0.9072
# current epoch: 56 current mean dice: 0.4709 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 57/300
# local epoch for train_loader 1: 57/300
# Loss for client: 1 :0.9332739189267159
# Loss C1: 0.9332739189267159
# local epoch for train_loader 2: 57/300
# Loss for client: 2 :0.834344208240509
# Loss C2: 0.834344208240509
# local epoch for train_loader 4: 57/300
# Loss for client: 4 :0.9485865712165833
# Loss C4: 0.9485865712165833
# train_loss: 0.9054
# ----------
# local epoch 58/300
# local epoch for train_loader 1: 58/300
# Loss for client: 1 :0.9321749806404114
# Loss C1: 0.9321749806404114
# local epoch for train_loader 2: 58/300
# Loss for client: 2 :0.8321291846888406
# Loss C2: 0.8321291846888406
# local epoch for train_loader 4: 58/300
# Loss for client: 4 :0.9478529691696167
# Loss C4: 0.9478529691696167
# train_loss: 0.9041
# current epoch: 58 current mean dice: 0.4657 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 59/300
# local epoch for train_loader 1: 59/300
# Loss for client: 1 :0.9309087544679642
# Loss C1: 0.9309087544679642
# local epoch for train_loader 2: 59/300
# Loss for client: 2 :0.8299376709120614
# Loss C2: 0.8299376709120614
# local epoch for train_loader 4: 59/300
# Loss for client: 4 :0.9468250274658203
# Loss C4: 0.9468250274658203
# train_loss: 0.9026
# ----------
# local epoch 60/300
# local epoch for train_loader 1: 60/300
# Loss for client: 1 :0.9296550676226616
# Loss C1: 0.9296550676226616
# local epoch for train_loader 2: 60/300
# Loss for client: 2 :0.825969778356098
# Loss C2: 0.825969778356098
# local epoch for train_loader 4: 60/300
# Loss for client: 4 :0.9459527254104614
# Loss C4: 0.9459527254104614
# train_loss: 0.9005
# current epoch: 60 current mean dice: 0.4677 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 61/300
# local epoch for train_loader 1: 61/300
# Loss for client: 1 :0.9283269345760345
# Loss C1: 0.9283269345760345
# local epoch for train_loader 2: 61/300
# Loss for client: 2 :0.8232770902769906
# Loss C2: 0.8232770902769906
# local epoch for train_loader 4: 61/300
# Loss for client: 4 :0.944844913482666
# Loss C4: 0.944844913482666
# train_loss: 0.8988
# ----------
# local epoch 62/300
# local epoch for train_loader 1: 62/300
# Loss for client: 1 :0.9272659495472908
# Loss C1: 0.9272659495472908
# local epoch for train_loader 2: 62/300
# Loss for client: 2 :0.8221344153086344
# Loss C2: 0.8221344153086344
# local epoch for train_loader 4: 62/300
# Loss for client: 4 :0.943990957736969
# Loss C4: 0.943990957736969
# train_loss: 0.8978
# current epoch: 62 current mean dice: 0.4612 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 63/300
# local epoch for train_loader 1: 63/300
# Loss for client: 1 :0.9258951172232628
# Loss C1: 0.9258951172232628
# local epoch for train_loader 2: 63/300
# Loss for client: 2 :0.8166812360286713
# Loss C2: 0.8166812360286713
# local epoch for train_loader 4: 63/300
# Loss for client: 4 :0.9429759025573731
# Loss C4: 0.9429759025573731
# train_loss: 0.8952
# ----------
# local epoch 64/300
# local epoch for train_loader 1: 64/300
# Loss for client: 1 :0.9244754239916801
# Loss C1: 0.9244754239916801
# local epoch for train_loader 2: 64/300
# Loss for client: 2 :0.8135242774373009
# Loss C2: 0.8135242774373009
# local epoch for train_loader 4: 64/300
# Loss for client: 4 :0.9419884085655212
# Loss C4: 0.9419884085655212
# train_loss: 0.8933
# current epoch: 64 current mean dice: 0.4406 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 65/300
# local epoch for train_loader 1: 65/300
# Loss for client: 1 :0.9229615926742554
# Loss C1: 0.9229615926742554
# local epoch for train_loader 2: 65/300
# Loss for client: 2 :0.8111789396830967
# Loss C2: 0.8111789396830967
# local epoch for train_loader 4: 65/300
# Loss for client: 4 :0.9409103751182556
# Loss C4: 0.9409103751182556
# train_loss: 0.8917
# ----------
# local epoch 66/300
# local epoch for train_loader 1: 66/300
# Loss for client: 1 :0.9216399267315865
# Loss C1: 0.9216399267315865
# local epoch for train_loader 2: 66/300
# Loss for client: 2 :0.8082646684987205
# Loss C2: 0.8082646684987205
# local epoch for train_loader 4: 66/300
# Loss for client: 4 :0.9400380611419678
# Loss C4: 0.9400380611419678
# train_loss: 0.8900
# current epoch: 66 current mean dice: 0.4754 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 67/300
# local epoch for train_loader 1: 67/300
# Loss for client: 1 :0.9203807413578033
# Loss C1: 0.9203807413578033
# local epoch for train_loader 2: 67/300
# Loss for client: 2 :0.8050917188326517
# Loss C2: 0.8050917188326517
# local epoch for train_loader 4: 67/300
# Loss for client: 4 :0.9388161182403565
# Loss C4: 0.9388161182403565
# train_loss: 0.8881
# ----------
# local epoch 68/300
# local epoch for train_loader 1: 68/300
# Loss for client: 1 :0.918642170727253
# Loss C1: 0.918642170727253
# local epoch for train_loader 2: 68/300
# Loss for client: 2 :0.8017333107335227
# Loss C2: 0.8017333107335227
# local epoch for train_loader 4: 68/300
# Loss for client: 4 :0.9377820730209351
# Loss C4: 0.9377820730209351
# train_loss: 0.8861
# current epoch: 68 current mean dice: 0.4937 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 69/300
# local epoch for train_loader 1: 69/300
# Loss for client: 1 :0.9172748476266861
# Loss C1: 0.9172748476266861
# local epoch for train_loader 2: 69/300
# Loss for client: 2 :0.7982056112516493
# Loss C2: 0.7982056112516493
# local epoch for train_loader 4: 69/300
# Loss for client: 4 :0.9367417335510254
# Loss C4: 0.9367417335510254
# train_loss: 0.8841
# ----------
# local epoch 70/300
# local epoch for train_loader 1: 70/300
# Loss for client: 1 :0.9157213866710663
# Loss C1: 0.9157213866710663
# local epoch for train_loader 2: 70/300
# Loss for client: 2 :0.794753603992008
# Loss C2: 0.794753603992008
# local epoch for train_loader 4: 70/300
# Loss for client: 4 :0.9356222033500672
# Loss C4: 0.9356222033500672
# train_loss: 0.8820
# current epoch: 70 current mean dice: 0.4951 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 71/300
# local epoch for train_loader 1: 71/300
# Loss for client: 1 :0.9141985103487968
# Loss C1: 0.9141985103487968
# local epoch for train_loader 2: 71/300
# Loss for client: 2 :0.7914848952066331
# Loss C2: 0.7914848952066331
# local epoch for train_loader 4: 71/300
# Loss for client: 4 :0.9345135688781738
# Loss C4: 0.9345135688781738
# train_loss: 0.8801
# ----------
# local epoch 72/300
# local epoch for train_loader 1: 72/300
# Loss for client: 1 :0.912622444331646
# Loss C1: 0.912622444331646
# local epoch for train_loader 2: 72/300
# Loss for client: 2 :0.7888743252981276
# Loss C2: 0.7888743252981276
# local epoch for train_loader 4: 72/300
# Loss for client: 4 :0.9333128213882447
# Loss C4: 0.9333128213882447
# train_loss: 0.8783
# current epoch: 72 current mean dice: 0.4875 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 73/300
# local epoch for train_loader 1: 73/300
# Loss for client: 1 :0.9110294356942177
# Loss C1: 0.9110294356942177
# local epoch for train_loader 2: 73/300
# Loss for client: 2 :0.7868065791470664
# Loss C2: 0.7868065791470664
# local epoch for train_loader 4: 73/300
# Loss for client: 4 :0.9321571588516235
# Loss C4: 0.9321571588516235
# train_loss: 0.8767
# ----------
# local epoch 74/300
# local epoch for train_loader 1: 74/300
# Loss for client: 1 :0.9096586182713509
# Loss C1: 0.9096586182713509
# local epoch for train_loader 2: 74/300
# Loss for client: 2 :0.7806577710878282
# Loss C2: 0.7806577710878282
# local epoch for train_loader 4: 74/300
# Loss for client: 4 :0.9310304284095764
# Loss C4: 0.9310304284095764
# train_loss: 0.8738
# current epoch: 74 current mean dice: 0.4917 best mean dice: 0.4954 at epoch 30
# ----------
# local epoch 75/300
# local epoch for train_loader 1: 75/300
# Loss for client: 1 :0.9079164937138557
# Loss C1: 0.9079164937138557
# local epoch for train_loader 2: 75/300
# Loss for client: 2 :0.777501866931007
# Loss C2: 0.777501866931007
# local epoch for train_loader 4: 75/300
# Loss for client: 4 :0.9299020767211914
# Loss C4: 0.9299020767211914
# train_loss: 0.8718
# ----------
# local epoch 76/300
# local epoch for train_loader 1: 76/300
# Loss for client: 1 :0.9063466712832451
# Loss C1: 0.9063466712832451
# local epoch for train_loader 2: 76/300
# Loss for client: 2 :0.7749936509700048
# Loss C2: 0.7749936509700048
# local epoch for train_loader 4: 76/300
# Loss for client: 4 :0.9285390615463257
# Loss C4: 0.9285390615463257
# train_loss: 0.8700
# saved new best metric model
# current epoch: 76 current mean dice: 0.5056 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 77/300
# local epoch for train_loader 1: 77/300
# Loss for client: 1 :0.9051742702722549
# Loss C1: 0.9051742702722549
# local epoch for train_loader 2: 77/300
# Loss for client: 2 :0.7705899249939692
# Loss C2: 0.7705899249939692
# local epoch for train_loader 4: 77/300
# Loss for client: 4 :0.9280226588249206
# Loss C4: 0.9280226588249206
# train_loss: 0.8679
# ----------
# local epoch 78/300
# local epoch for train_loader 1: 78/300
# Loss for client: 1 :0.9028652682900429
# Loss C1: 0.9028652682900429
# local epoch for train_loader 2: 78/300
# Loss for client: 2 :0.7682150119826907
# Loss C2: 0.7682150119826907
# local epoch for train_loader 4: 78/300
# Loss for client: 4 :0.9261826038360595
# Loss C4: 0.9261826038360595
# train_loss: 0.8658
# current epoch: 78 current mean dice: 0.4968 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 79/300
# local epoch for train_loader 1: 79/300
# Loss for client: 1 :0.9014302864670753
# Loss C1: 0.9014302864670753
# local epoch for train_loader 2: 79/300
# Loss for client: 2 :0.7627588368597484
# Loss C2: 0.7627588368597484
# local epoch for train_loader 4: 79/300
# Loss for client: 4 :0.924822998046875
# Loss C4: 0.924822998046875
# train_loss: 0.8630
# ----------
# local epoch 80/300
# local epoch for train_loader 1: 80/300
# Loss for client: 1 :0.9000602439045906
# Loss C1: 0.9000602439045906
# local epoch for train_loader 2: 80/300
# Loss for client: 2 :0.7602475086847941
# Loss C2: 0.7602475086847941
# local epoch for train_loader 4: 80/300
# Loss for client: 4 :0.9237638473510742
# Loss C4: 0.9237638473510742
# train_loss: 0.8614
# current epoch: 80 current mean dice: 0.4729 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 81/300
# local epoch for train_loader 1: 81/300
# Loss for client: 1 :0.8977914676070213
# Loss C1: 0.8977914676070213
# local epoch for train_loader 2: 81/300
# Loss for client: 2 :0.7570515544641585
# Loss C2: 0.7570515544641585
# local epoch for train_loader 4: 81/300
# Loss for client: 4 :0.9226811289787292
# Loss C4: 0.9226811289787292
# train_loss: 0.8592
# ----------
# local epoch 82/300
# local epoch for train_loader 1: 82/300
# Loss for client: 1 :0.8960410133004189
# Loss C1: 0.8960410133004189
# local epoch for train_loader 2: 82/300
# Loss for client: 2 :0.7534278773126148
# Loss C2: 0.7534278773126148
# local epoch for train_loader 4: 82/300
# Loss for client: 4 :0.9215640187263489
# Loss C4: 0.9215640187263489
# train_loss: 0.8570
# current epoch: 82 current mean dice: 0.4898 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 83/300
# local epoch for train_loader 1: 83/300
# Loss for client: 1 :0.8943749815225601
# Loss C1: 0.8943749815225601
# local epoch for train_loader 2: 83/300
# Loss for client: 2 :0.7490462831088475
# Loss C2: 0.7490462831088475
# local epoch for train_loader 4: 83/300
# Loss for client: 4 :0.9198361873626709
# Loss C4: 0.9198361873626709
# train_loss: 0.8544
# ----------
# local epoch 84/300
# local epoch for train_loader 1: 84/300
# Loss for client: 1 :0.8924264907836914
# Loss C1: 0.8924264907836914
# local epoch for train_loader 2: 84/300
# Loss for client: 2 :0.7458713139806475
# Loss C2: 0.7458713139806475
# local epoch for train_loader 4: 84/300
# Loss for client: 4 :0.9184372305870057
# Loss C4: 0.9184372305870057
# train_loss: 0.8522
# current epoch: 84 current mean dice: 0.4790 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 85/300
# local epoch for train_loader 1: 85/300
# Loss for client: 1 :0.8902409672737122
# Loss C1: 0.8902409672737122
# local epoch for train_loader 2: 85/300
# Loss for client: 2 :0.7407442061674028
# Loss C2: 0.7407442061674028
# local epoch for train_loader 4: 85/300
# Loss for client: 4 :0.9171896696090698
# Loss C4: 0.9171896696090698
# train_loss: 0.8494
# ----------
# local epoch 86/300
# local epoch for train_loader 1: 86/300
# Loss for client: 1 :0.8904258161783218
# Loss C1: 0.8904258161783218
# local epoch for train_loader 2: 86/300
# Loss for client: 2 :0.7391288323061806
# Loss C2: 0.7391288323061806
# local epoch for train_loader 4: 86/300
# Loss for client: 4 :0.9158150911331177
# Loss C4: 0.9158150911331177
# train_loss: 0.8485
# current epoch: 86 current mean dice: 0.4862 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 87/300
# local epoch for train_loader 1: 87/300
# Loss for client: 1 :0.8905216977000237
# Loss C1: 0.8905216977000237
# local epoch for train_loader 2: 87/300
# Loss for client: 2 :0.7344201859973726
# Loss C2: 0.7344201859973726
# local epoch for train_loader 4: 87/300
# Loss for client: 4 :0.9145912528038025
# Loss C4: 0.9145912528038025
# train_loss: 0.8465
# ----------
# local epoch 88/300
# local epoch for train_loader 1: 88/300
# Loss for client: 1 :0.8851670548319817
# Loss C1: 0.8851670548319817
# local epoch for train_loader 2: 88/300
# Loss for client: 2 :0.733245910633178
# Loss C2: 0.733245910633178
# local epoch for train_loader 4: 88/300
# Loss for client: 4 :0.9133699536323547
# Loss C4: 0.9133699536323547
# train_loss: 0.8439
# current epoch: 88 current mean dice: 0.4823 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 89/300
# local epoch for train_loader 1: 89/300
# Loss for client: 1 :0.8837000951170921
# Loss C1: 0.8837000951170921
# local epoch for train_loader 2: 89/300
# Loss for client: 2 :0.7265031522228604
# Loss C2: 0.7265031522228604
# local epoch for train_loader 4: 89/300
# Loss for client: 4 :0.9120543241500855
# Loss C4: 0.9120543241500855
# train_loss: 0.8408
# ----------
# local epoch 90/300
# local epoch for train_loader 1: 90/300
# Loss for client: 1 :0.8819966092705727
# Loss C1: 0.8819966092705727
# local epoch for train_loader 2: 90/300
# Loss for client: 2 :0.7223233538014548
# Loss C2: 0.7223233538014548
# local epoch for train_loader 4: 90/300
# Loss for client: 4 :0.9104867935180664
# Loss C4: 0.9104867935180664
# train_loss: 0.8383
# current epoch: 90 current mean dice: 0.4653 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 91/300
# local epoch for train_loader 1: 91/300
# Loss for client: 1 :0.8793314322829247
# Loss C1: 0.8793314322829247
# local epoch for train_loader 2: 91/300
# Loss for client: 2 :0.7174233297506968
# Loss C2: 0.7174233297506968
# local epoch for train_loader 4: 91/300
# Loss for client: 4 :0.9090643405914307
# Loss C4: 0.9090643405914307
# train_loss: 0.8353
# ----------
# local epoch 92/300
# local epoch for train_loader 1: 92/300
# Loss for client: 1 :0.8767938911914825
# Loss C1: 0.8767938911914825
# local epoch for train_loader 2: 92/300
# Loss for client: 2 :0.716381691751026
# Loss C2: 0.716381691751026
# local epoch for train_loader 4: 92/300
# Loss for client: 4 :0.907481026649475
# Loss C4: 0.907481026649475
# train_loss: 0.8336
# current epoch: 92 current mean dice: 0.4701 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 93/300
# local epoch for train_loader 1: 93/300
# Loss for client: 1 :0.8747505843639374
# Loss C1: 0.8747505843639374
# local epoch for train_loader 2: 93/300
# Loss for client: 2 :0.7104982960791815
# Loss C2: 0.7104982960791815
# local epoch for train_loader 4: 93/300
# Loss for client: 4 :0.9060284495353699
# Loss C4: 0.9060284495353699
# train_loss: 0.8304
# ----------
# local epoch 94/300
# local epoch for train_loader 1: 94/300
# Loss for client: 1 :0.8728508204221725
# Loss C1: 0.8728508204221725
# local epoch for train_loader 2: 94/300
# Loss for client: 2 :0.7092631516002473
# Loss C2: 0.7092631516002473
# local epoch for train_loader 4: 94/300
# Loss for client: 4 :0.9080955505371093
# Loss C4: 0.9080955505371093
# train_loss: 0.8301
# current epoch: 94 current mean dice: 0.4799 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 95/300
# local epoch for train_loader 1: 95/300
# Loss for client: 1 :0.8709530159831047
# Loss C1: 0.8709530159831047
# local epoch for train_loader 2: 95/300
# Loss for client: 2 :0.7042496999104818
# Loss C2: 0.7042496999104818
# local epoch for train_loader 4: 95/300
# Loss for client: 4 :0.9037509679794311
# Loss C4: 0.9037509679794311
# train_loss: 0.8263
# ----------
# local epoch 96/300
# local epoch for train_loader 1: 96/300
# Loss for client: 1 :0.8696858137845993
# Loss C1: 0.8696858137845993
# local epoch for train_loader 2: 96/300
# Loss for client: 2 :0.6999172426405407
# Loss C2: 0.6999172426405407
# local epoch for train_loader 4: 96/300
# Loss for client: 4 :0.9017786383628845
# Loss C4: 0.9017786383628845
# train_loss: 0.8238
# current epoch: 96 current mean dice: 0.4985 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 97/300
# local epoch for train_loader 1: 97/300
# Loss for client: 1 :0.8669188097119331
# Loss C1: 0.8669188097119331
# local epoch for train_loader 2: 97/300
# Loss for client: 2 :0.6967727584498269
# Loss C2: 0.6967727584498269
# local epoch for train_loader 4: 97/300
# Loss for client: 4 :0.9009028315544129
# Loss C4: 0.9009028315544129
# train_loss: 0.8215
# ----------
# local epoch 98/300
# local epoch for train_loader 1: 98/300
# Loss for client: 1 :0.8643683269619942
# Loss C1: 0.8643683269619942
# local epoch for train_loader 2: 98/300
# Loss for client: 2 :0.6959634281340099
# Loss C2: 0.6959634281340099
# local epoch for train_loader 4: 98/300
# Loss for client: 4 :0.8998374700546264
# Loss C4: 0.8998374700546264
# train_loss: 0.8201
# current epoch: 98 current mean dice: 0.4991 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 99/300
# local epoch for train_loader 1: 99/300
# Loss for client: 1 :0.8631963580846786
# Loss C1: 0.8631963580846786
# local epoch for train_loader 2: 99/300
# Loss for client: 2 :0.6864470867883592
# Loss C2: 0.6864470867883592
# local epoch for train_loader 4: 99/300
# Loss for client: 4 :0.8978552699089051
# Loss C4: 0.8978552699089051
# train_loss: 0.8158
# ----------
# local epoch 100/300
# local epoch for train_loader 1: 100/300
# Loss for client: 1 :0.859998531639576
# Loss C1: 0.859998531639576
# local epoch for train_loader 2: 100/300
# Loss for client: 2 :0.6827023994354975
# Loss C2: 0.6827023994354975
# local epoch for train_loader 4: 100/300
# Loss for client: 4 :0.8958810448646546
# Loss C4: 0.8958810448646546
# train_loss: 0.8129
# current epoch: 100 current mean dice: 0.4854 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 101/300
# local epoch for train_loader 1: 101/300
# Loss for client: 1 :0.8589165434241295
# Loss C1: 0.8589165434241295
# local epoch for train_loader 2: 101/300
# Loss for client: 2 :0.6779787214029402
# Loss C2: 0.6779787214029402
# local epoch for train_loader 4: 101/300
# Loss for client: 4 :0.8949430823326111
# Loss C4: 0.8949430823326111
# train_loss: 0.8106
# ----------
# local epoch 102/300
# local epoch for train_loader 1: 102/300
# Loss for client: 1 :0.8558307886123657
# Loss C1: 0.8558307886123657
# local epoch for train_loader 2: 102/300
# Loss for client: 2 :0.6728959168706622
# Loss C2: 0.6728959168706622
# local epoch for train_loader 4: 102/300
# Loss for client: 4 :0.8929425001144409
# Loss C4: 0.8929425001144409
# train_loss: 0.8072
# current epoch: 102 current mean dice: 0.4749 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 103/300
# local epoch for train_loader 1: 103/300
# Loss for client: 1 :0.853816457092762
# Loss C1: 0.853816457092762
# local epoch for train_loader 2: 103/300
# Loss for client: 2 :0.6724902093410492
# Loss C2: 0.6724902093410492
# local epoch for train_loader 4: 103/300
# Loss for client: 4 :0.8911624550819397
# Loss C4: 0.8911624550819397
# train_loss: 0.8058
# ----------
# local epoch 104/300
# local epoch for train_loader 1: 104/300
# Loss for client: 1 :0.8514696732163429
# Loss C1: 0.8514696732163429
# local epoch for train_loader 2: 104/300
# Loss for client: 2 :0.6654774617581141
# Loss C2: 0.6654774617581141
# local epoch for train_loader 4: 104/300
# Loss for client: 4 :0.8901310443878174
# Loss C4: 0.8901310443878174
# train_loss: 0.8024
# current epoch: 104 current mean dice: 0.4410 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 105/300
# local epoch for train_loader 1: 105/300
# Loss for client: 1 :0.8496160060167313
# Loss C1: 0.8496160060167313
# local epoch for train_loader 2: 105/300
# Loss for client: 2 :0.6622315574259985
# Loss C2: 0.6622315574259985
# local epoch for train_loader 4: 105/300
# Loss for client: 4 :0.8889500141143799
# Loss C4: 0.8889500141143799
# train_loss: 0.8003
# ----------
# local epoch 106/300
# local epoch for train_loader 1: 106/300
# Loss for client: 1 :0.8470288515090942
# Loss C1: 0.8470288515090942
# local epoch for train_loader 2: 106/300
# Loss for client: 2 :0.6604644869055066
# Loss C2: 0.6604644869055066
# local epoch for train_loader 4: 106/300
# Loss for client: 4 :0.8880025386810303
# Loss C4: 0.8880025386810303
# train_loss: 0.7985
# current epoch: 106 current mean dice: 0.4770 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 107/300
# local epoch for train_loader 1: 107/300
# Loss for client: 1 :0.845484122633934
# Loss C1: 0.845484122633934
# local epoch for train_loader 2: 107/300
# Loss for client: 2 :0.6548037628332773
# Loss C2: 0.6548037628332773
# local epoch for train_loader 4: 107/300
# Loss for client: 4 :0.8858703970909119
# Loss C4: 0.8858703970909119
# train_loss: 0.7954
# ----------
# local epoch 108/300
# local epoch for train_loader 1: 108/300
# Loss for client: 1 :0.8429002240300179
# Loss C1: 0.8429002240300179
# local epoch for train_loader 2: 108/300
# Loss for client: 2 :0.6500410111177535
# Loss C2: 0.6500410111177535
# local epoch for train_loader 4: 108/300
# Loss for client: 4 :0.8836272478103637
# Loss C4: 0.8836272478103637
# train_loss: 0.7922
# current epoch: 108 current mean dice: 0.4729 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 109/300
# local epoch for train_loader 1: 109/300
# Loss for client: 1 :0.8403853625059128
# Loss C1: 0.8403853625059128
# local epoch for train_loader 2: 109/300
# Loss for client: 2 :0.6437716753709883
# Loss C2: 0.6437716753709883
# local epoch for train_loader 4: 109/300
# Loss for client: 4 :0.8822461485862731
# Loss C4: 0.8822461485862731
# train_loss: 0.7888
# ----------
# local epoch 110/300
# local epoch for train_loader 1: 110/300
# Loss for client: 1 :0.8368773907423019
# Loss C1: 0.8368773907423019
# local epoch for train_loader 2: 110/300
# Loss for client: 2 :0.639383526075454
# Loss C2: 0.639383526075454
# local epoch for train_loader 4: 110/300
# Loss for client: 4 :0.8803739666938781
# Loss C4: 0.8803739666938781
# train_loss: 0.7855
# current epoch: 110 current mean dice: 0.4844 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 111/300
# local epoch for train_loader 1: 111/300
# Loss for client: 1 :0.8398026302456856
# Loss C1: 0.8398026302456856
# local epoch for train_loader 2: 111/300
# Loss for client: 2 :0.6348590084484645
# Loss C2: 0.6348590084484645
# local epoch for train_loader 4: 111/300
# Loss for client: 4 :0.8795552372932434
# Loss C4: 0.8795552372932434
# train_loss: 0.7847
# ----------
# local epoch 112/300
# local epoch for train_loader 1: 112/300
# Loss for client: 1 :0.8337336257100105
# Loss C1: 0.8337336257100105
# local epoch for train_loader 2: 112/300
# Loss for client: 2 :0.6343610712460109
# Loss C2: 0.6343610712460109
# local epoch for train_loader 4: 112/300
# Loss for client: 4 :0.8782134771347045
# Loss C4: 0.8782134771347045
# train_loss: 0.7821
# current epoch: 112 current mean dice: 0.4993 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 113/300
# local epoch for train_loader 1: 113/300
# Loss for client: 1 :0.830779954791069
# Loss C1: 0.830779954791069
# local epoch for train_loader 2: 113/300
# Loss for client: 2 :0.626472859155564
# Loss C2: 0.626472859155564
# local epoch for train_loader 4: 113/300
# Loss for client: 4 :0.87775958776474
# Loss C4: 0.87775958776474
# train_loss: 0.7783
# ----------
# local epoch 114/300
# local epoch for train_loader 1: 114/300
# Loss for client: 1 :0.8276289999485016
# Loss C1: 0.8276289999485016
# local epoch for train_loader 2: 114/300
# Loss for client: 2 :0.6245799689065843
# Loss C2: 0.6245799689065843
# local epoch for train_loader 4: 114/300
# Loss for client: 4 :0.8742066502571106
# Loss C4: 0.8742066502571106
# train_loss: 0.7755
# current epoch: 114 current mean dice: 0.4991 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 115/300
# local epoch for train_loader 1: 115/300
# Loss for client: 1 :0.8254181370139122
# Loss C1: 0.8254181370139122
# local epoch for train_loader 2: 115/300
# Loss for client: 2 :0.6214441387426286
# Loss C2: 0.6214441387426286
# local epoch for train_loader 4: 115/300
# Loss for client: 4 :0.8735060572624207
# Loss C4: 0.8735060572624207
# train_loss: 0.7735
# ----------
# local epoch 116/300
# local epoch for train_loader 1: 116/300
# Loss for client: 1 :0.8258794099092484
# Loss C1: 0.8258794099092484
# local epoch for train_loader 2: 116/300
# Loss for client: 2 :0.6172793280510676
# Loss C2: 0.6172793280510676
# local epoch for train_loader 4: 116/300
# Loss for client: 4 :0.8718388319015503
# Loss C4: 0.8718388319015503
# train_loss: 0.7717
# current epoch: 116 current mean dice: 0.4874 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 117/300
# local epoch for train_loader 1: 117/300
# Loss for client: 1 :0.8228135332465172
# Loss C1: 0.8228135332465172
# local epoch for train_loader 2: 117/300
# Loss for client: 2 :0.6113387573333013
# Loss C2: 0.6113387573333013
# local epoch for train_loader 4: 117/300
# Loss for client: 4 :0.8705605626106262
# Loss C4: 0.8705605626106262
# train_loss: 0.7682
# ----------
# local epoch 118/300
# local epoch for train_loader 1: 118/300
# Loss for client: 1 :0.823543343693018
# Loss C1: 0.823543343693018
# local epoch for train_loader 2: 118/300
# Loss for client: 2 :0.6091545479638236
# Loss C2: 0.6091545479638236
# ...
# Loss for client: 2 :0.07866448589733668
# Loss C2: 0.07866448589733668
# local epoch for train_loader 4: 262/300
# Loss for client: 4 :0.7048829972743988
# Loss C4: 0.7048829972743988
# train_loss: 0.3626
# current epoch: 262 current mean dice: 0.1542 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 263/300
# local epoch for train_loader 1: 263/300
# Loss for client: 1 :0.2992759384214878
# Loss C1: 0.2992759384214878
# local epoch for train_loader 2: 263/300
# Loss for client: 2 :0.08518570093881517
# Loss C2: 0.08518570093881517
# local epoch for train_loader 4: 263/300
# Loss for client: 4 :0.7039399147033691
# Loss C4: 0.7039399147033691
# train_loss: 0.3628
# ----------
# local epoch 264/300
# local epoch for train_loader 1: 264/300
# Loss for client: 1 :0.3040863238275051
# Loss C1: 0.3040863238275051
# local epoch for train_loader 2: 264/300
# Loss for client: 2 :0.08834247220130194
# Loss C2: 0.08834247220130194
# local epoch for train_loader 4: 264/300
# Loss for client: 4 :0.7055727183818817
# Loss C4: 0.7055727183818817
# train_loss: 0.3660
# current epoch: 264 current mean dice: 0.1954 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 265/300
# local epoch for train_loader 1: 265/300
# Loss for client: 1 :0.30951035767793655
# Loss C1: 0.30951035767793655
# local epoch for train_loader 2: 265/300
# Loss for client: 2 :0.08018899531591506
# Loss C2: 0.08018899531591506
# local epoch for train_loader 4: 265/300
# Loss for client: 4 :0.7044617593288421
# Loss C4: 0.7044617593288421
# train_loss: 0.3647
# ----------
# local epoch 266/300
# local epoch for train_loader 1: 266/300
# Loss for client: 1 :0.3084537163376808
# Loss C1: 0.3084537163376808
# local epoch for train_loader 2: 266/300
# Loss for client: 2 :0.08643044460387457
# Loss C2: 0.08643044460387457
# local epoch for train_loader 4: 266/300
# Loss for client: 4 :0.7051829934120178
# Loss C4: 0.7051829934120178
# train_loss: 0.3667
# current epoch: 266 current mean dice: 0.2502 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 267/300
# local epoch for train_loader 1: 267/300
# Loss for client: 1 :0.3042246773838997
# Loss C1: 0.3042246773838997
# local epoch for train_loader 2: 267/300
# Loss for client: 2 :0.07908203062557038
# Loss C2: 0.07908203062557038
# local epoch for train_loader 4: 267/300
# Loss for client: 4 :0.7042586624622345
# Loss C4: 0.7042586624622345
# train_loss: 0.3625
# ----------
# local epoch 268/300
# local epoch for train_loader 1: 268/300
# Loss for client: 1 :0.3028194531798363
# Loss C1: 0.3028194531798363
# local epoch for train_loader 2: 268/300
# Loss for client: 2 :0.08197921656426929
# Loss C2: 0.08197921656426929
# local epoch for train_loader 4: 268/300
# Loss for client: 4 :0.7051492393016815
# Loss C4: 0.7051492393016815
# train_loss: 0.3633
# current epoch: 268 current mean dice: 0.1338 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 269/300
# local epoch for train_loader 1: 269/300
# Loss for client: 1 :0.30070139467716217
# Loss C1: 0.30070139467716217
# local epoch for train_loader 2: 269/300
# Loss for client: 2 :0.07807792652220953
# Loss C2: 0.07807792652220953
# local epoch for train_loader 4: 269/300
# Loss for client: 4 :0.705878221988678
# Loss C4: 0.705878221988678
# train_loss: 0.3616
# ----------
# local epoch 270/300
# local epoch for train_loader 1: 270/300
# Loss for client: 1 :0.302412535995245
# Loss C1: 0.302412535995245
# local epoch for train_loader 2: 270/300
# Loss for client: 2 :0.08023019631703694
# Loss C2: 0.08023019631703694
# local epoch for train_loader 4: 270/300
# Loss for client: 4 :0.7033467948436737
# Loss C4: 0.7033467948436737
# train_loss: 0.3620
# current epoch: 270 current mean dice: 0.1250 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 271/300
# local epoch for train_loader 1: 271/300
# Loss for client: 1 :0.29986510798335075
# Loss C1: 0.29986510798335075
# local epoch for train_loader 2: 271/300
# Loss for client: 2 :0.0790226019564129
# Loss C2: 0.0790226019564129
# local epoch for train_loader 4: 271/300
# Loss for client: 4 :0.7042855858802796
# Loss C4: 0.7042855858802796
# train_loss: 0.3611
# ----------
# local epoch 272/300
# local epoch for train_loader 1: 272/300
# Loss for client: 1 :0.3019890822470188
# Loss C1: 0.3019890822470188
# local epoch for train_loader 2: 272/300
# Loss for client: 2 :0.08018189952487037
# Loss C2: 0.08018189952487037
# local epoch for train_loader 4: 272/300
# Loss for client: 4 :0.704770702123642
# Loss C4: 0.704770702123642
# train_loss: 0.3623
# current epoch: 272 current mean dice: 0.1769 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 273/300
# local epoch for train_loader 1: 273/300
# Loss for client: 1 :0.30059409514069557
# Loss C1: 0.30059409514069557
# local epoch for train_loader 2: 273/300
# Loss for client: 2 :0.07741844937914893
# Loss C2: 0.07741844937914893
# local epoch for train_loader 4: 273/300
# Loss for client: 4 :0.7033820390701294
# Loss C4: 0.7033820390701294
# train_loss: 0.3605
# ----------
# local epoch 274/300
# local epoch for train_loader 1: 274/300
# Loss for client: 1 :0.3045240715146065
# Loss C1: 0.3045240715146065
# local epoch for train_loader 2: 274/300
# Loss for client: 2 :0.08166657317252386
# Loss C2: 0.08166657317252386
# local epoch for train_loader 4: 274/300
# Loss for client: 4 :0.7038959801197052
# Loss C4: 0.7038959801197052
# train_loss: 0.3634
# current epoch: 274 current mean dice: 0.1895 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 275/300
# local epoch for train_loader 1: 275/300
# Loss for client: 1 :0.2973325066268444
# Loss C1: 0.2973325066268444
# local epoch for train_loader 2: 275/300
# Loss for client: 2 :0.07693934298696972
# Loss C2: 0.07693934298696972
# local epoch for train_loader 4: 275/300
# Loss for client: 4 :0.7033668220043182
# Loss C4: 0.7033668220043182
# train_loss: 0.3592
# ----------
# local epoch 276/300
# local epoch for train_loader 1: 276/300
# Loss for client: 1 :0.29549938812851906
# Loss C1: 0.29549938812851906
# local epoch for train_loader 2: 276/300
# Loss for client: 2 :0.07588161315236773
# Loss C2: 0.07588161315236773
# local epoch for train_loader 4: 276/300
# Loss for client: 4 :0.7032810926437378
# Loss C4: 0.7032810926437378
# train_loss: 0.3582
# current epoch: 276 current mean dice: 0.1997 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 277/300
# local epoch for train_loader 1: 277/300
# Loss for client: 1 :0.29794393479824066
# Loss C1: 0.29794393479824066
# local epoch for train_loader 2: 277/300
# Loss for client: 2 :0.07559488500867571
# Loss C2: 0.07559488500867571
# local epoch for train_loader 4: 277/300
# Loss for client: 4 :0.702701723575592
# Loss C4: 0.702701723575592
# train_loss: 0.3587
# ----------
# local epoch 278/300
# local epoch for train_loader 1: 278/300
# Loss for client: 1 :0.2932909466326237
# Loss C1: 0.2932909466326237
# local epoch for train_loader 2: 278/300
# Loss for client: 2 :0.07788319672857012
# Loss C2: 0.07788319672857012
# local epoch for train_loader 4: 278/300
# Loss for client: 4 :0.7033595621585846
# Loss C4: 0.7033595621585846
# train_loss: 0.3582
# current epoch: 278 current mean dice: 0.2330 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 279/300
# local epoch for train_loader 1: 279/300
# Loss for client: 1 :0.30220356583595276
# Loss C1: 0.30220356583595276
# local epoch for train_loader 2: 279/300
# Loss for client: 2 :0.07603829105695088
# Loss C2: 0.07603829105695088
# local epoch for train_loader 4: 279/300
# Loss for client: 4 :0.7043958246707916
# Loss C4: 0.7043958246707916
# train_loss: 0.3609
# ----------
# local epoch 280/300
# local epoch for train_loader 1: 280/300
# Loss for client: 1 :0.3022559694945812
# Loss C1: 0.3022559694945812
# local epoch for train_loader 2: 280/300
# Loss for client: 2 :0.0749609371026357
# Loss C2: 0.0749609371026357
# local epoch for train_loader 4: 280/300
# Loss for client: 4 :0.704253488779068
# Loss C4: 0.704253488779068
# train_loss: 0.3605
# current epoch: 280 current mean dice: 0.1780 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 281/300
# local epoch for train_loader 1: 281/300
# Loss for client: 1 :0.3072713017463684
# Loss C1: 0.3072713017463684
# local epoch for train_loader 2: 281/300
# Loss for client: 2 :0.07685799116180056
# Loss C2: 0.07685799116180056
# local epoch for train_loader 4: 281/300
# Loss for client: 4 :0.7029402315616607
# Loss C4: 0.7029402315616607
# train_loss: 0.3624
# ----------
# local epoch 282/300
# local epoch for train_loader 1: 282/300
# Loss for client: 1 :0.30023369938135147
# Loss C1: 0.30023369938135147
# local epoch for train_loader 2: 282/300
# Loss for client: 2 :0.07481138479141962
# Loss C2: 0.07481138479141962
# local epoch for train_loader 4: 282/300
# Loss for client: 4 :0.703129380941391
# Loss C4: 0.703129380941391
# train_loss: 0.3594
# current epoch: 282 current mean dice: 0.2201 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 283/300
# local epoch for train_loader 1: 283/300
# Loss for client: 1 :0.296327106654644
# Loss C1: 0.296327106654644
# local epoch for train_loader 2: 283/300
# Loss for client: 2 :0.07697542224611555
# Loss C2: 0.07697542224611555
# local epoch for train_loader 4: 283/300
# Loss for client: 4 :0.7040723741054535
# Loss C4: 0.7040723741054535
# train_loss: 0.3591
# ----------
# local epoch 284/300
# local epoch for train_loader 1: 284/300
# Loss for client: 1 :0.295732282102108
# Loss C1: 0.295732282102108
# local epoch for train_loader 2: 284/300
# Loss for client: 2 :0.07435358705974761
# Loss C2: 0.07435358705974761
# local epoch for train_loader 4: 284/300
# Loss for client: 4 :0.7045413792133332
# Loss C4: 0.7045413792133332
# train_loss: 0.3582
# current epoch: 284 current mean dice: 0.1745 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 285/300
# local epoch for train_loader 1: 285/300
# Loss for client: 1 :0.30079931765794754
# Loss C1: 0.30079931765794754
# local epoch for train_loader 2: 285/300
# Loss for client: 2 :0.07354078406379336
# Loss C2: 0.07354078406379336
# local epoch for train_loader 4: 285/300
# Loss for client: 4 :0.7043878674507141
# Loss C4: 0.7043878674507141
# train_loss: 0.3596
# ----------
# local epoch 286/300
# local epoch for train_loader 1: 286/300
# Loss for client: 1 :0.3000413440167904
# Loss C1: 0.3000413440167904
# local epoch for train_loader 2: 286/300
# Loss for client: 2 :0.07961539427439372
# Loss C2: 0.07961539427439372
# local epoch for train_loader 4: 286/300
# Loss for client: 4 :0.7026000201702118
# Loss C4: 0.7026000201702118
# train_loss: 0.3608
# current epoch: 286 current mean dice: 0.1965 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 287/300
# local epoch for train_loader 1: 287/300
# Loss for client: 1 :0.29523104801774025
# Loss C1: 0.29523104801774025
# local epoch for train_loader 2: 287/300
# Loss for client: 2 :0.07112369083222889
# Loss C2: 0.07112369083222889
# local epoch for train_loader 4: 287/300
# Loss for client: 4 :0.7035713016986846
# Loss C4: 0.7035713016986846
# train_loss: 0.3566
# ----------
# local epoch 288/300
# local epoch for train_loader 1: 288/300
# Loss for client: 1 :0.2947438657283783
# Loss C1: 0.2947438657283783
# local epoch for train_loader 2: 288/300
# Loss for client: 2 :0.07418363151096162
# Loss C2: 0.07418363151096162
# local epoch for train_loader 4: 288/300
# Loss for client: 4 :0.7036092400550842
# Loss C4: 0.7036092400550842
# train_loss: 0.3575
# current epoch: 288 current mean dice: 0.1948 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 289/300
# local epoch for train_loader 1: 289/300
# Loss for client: 1 :0.3028608225286007
# Loss C1: 0.3028608225286007
# local epoch for train_loader 2: 289/300
# Loss for client: 2 :0.07475684654145014
# Loss C2: 0.07475684654145014
# local epoch for train_loader 4: 289/300
# Loss for client: 4 :0.7030059576034546
# Loss C4: 0.7030059576034546
# train_loss: 0.3602
# ----------
# local epoch 290/300
# local epoch for train_loader 1: 290/300
# Loss for client: 1 :0.2962909899652004
# Loss C1: 0.2962909899652004
# local epoch for train_loader 2: 290/300
# Loss for client: 2 :0.07390784649621873
# Loss C2: 0.07390784649621873
# local epoch for train_loader 4: 290/300
# Loss for client: 4 :0.7029108107089996
# Loss C4: 0.7029108107089996
# train_loss: 0.3577
# current epoch: 290 current mean dice: 0.2335 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 291/300
# local epoch for train_loader 1: 291/300
# Loss for client: 1 :0.30090219900012016
# Loss C1: 0.30090219900012016
# local epoch for train_loader 2: 291/300
# Loss for client: 2 :0.07308826843897502
# Loss C2: 0.07308826843897502
# local epoch for train_loader 4: 291/300
# Loss for client: 4 :0.7039967715740204
# Loss C4: 0.7039967715740204
# train_loss: 0.3593
# ----------
# local epoch 292/300
# local epoch for train_loader 1: 292/300
# Loss for client: 1 :0.2970314100384712
# Loss C1: 0.2970314100384712
# local epoch for train_loader 2: 292/300
# Loss for client: 2 :0.06935801960173107
# Loss C2: 0.06935801960173107
# local epoch for train_loader 4: 292/300
# Loss for client: 4 :0.705787718296051
# Loss C4: 0.705787718296051
# train_loss: 0.3574
# current epoch: 292 current mean dice: 0.1763 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 293/300
# local epoch for train_loader 1: 293/300
# Loss for client: 1 :0.2914303317666054
# Loss C1: 0.2914303317666054
# local epoch for train_loader 2: 293/300
# Loss for client: 2 :0.0716469373021807
# Loss C2: 0.0716469373021807
# local epoch for train_loader 4: 293/300
# Loss for client: 4 :0.7020489275455475
# Loss C4: 0.7020489275455475
# train_loss: 0.3550
# ----------
# local epoch 294/300
# local epoch for train_loader 1: 294/300
# Loss for client: 1 :0.30157453939318657
# Loss C1: 0.30157453939318657
# local epoch for train_loader 2: 294/300
# Loss for client: 2 :0.0722655767486209
# Loss C2: 0.0722655767486209
# local epoch for train_loader 4: 294/300
# Loss for client: 4 :0.7031428992748261
# Loss C4: 0.7031428992748261
# train_loss: 0.3590
# current epoch: 294 current mean dice: 0.1749 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 295/300
# local epoch for train_loader 1: 295/300
# Loss for client: 1 :0.29361821711063385
# Loss C1: 0.29361821711063385
# local epoch for train_loader 2: 295/300
# Loss for client: 2 :0.07413235448655628
# Loss C2: 0.07413235448655628
# local epoch for train_loader 4: 295/300
# Loss for client: 4 :0.7024984657764435
# Loss C4: 0.7024984657764435
# train_loss: 0.3567
# ----------
# local epoch 296/300
# local epoch for train_loader 1: 296/300
# Loss for client: 1 :0.2966235466301441
# Loss C1: 0.2966235466301441
# local epoch for train_loader 2: 296/300
# Loss for client: 2 :0.0706003989492144
# Loss C2: 0.0706003989492144
# local epoch for train_loader 4: 296/300
# Loss for client: 4 :0.7033497035503388
# Loss C4: 0.7033497035503388
# train_loss: 0.3569
# current epoch: 296 current mean dice: 0.2034 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 297/300
# local epoch for train_loader 1: 297/300
# Loss for client: 1 :0.29682714864611626
# Loss C1: 0.29682714864611626
# local epoch for train_loader 2: 297/300
# Loss for client: 2 :0.07586528006054107
# Loss C2: 0.07586528006054107
# local epoch for train_loader 4: 297/300
# Loss for client: 4 :0.7039996683597565
# Loss C4: 0.7039996683597565
# train_loss: 0.3589
# ----------
# local epoch 298/300
# local epoch for train_loader 1: 298/300
# Loss for client: 1 :0.2906356006860733
# Loss C1: 0.2906356006860733
# local epoch for train_loader 2: 298/300
# Loss for client: 2 :0.07295621718679156
# Loss C2: 0.07295621718679156
# local epoch for train_loader 4: 298/300
# Loss for client: 4 :0.7025575816631318
# Loss C4: 0.7025575816631318
# train_loss: 0.3554
# current epoch: 298 current mean dice: 0.2051 best mean dice: 0.5056 at epoch 76
# ----------
# local epoch 299/300
# local epoch for train_loader 1: 299/300
# Loss for client: 1 :0.2933850511908531
# Loss C1: 0.2933850511908531
# local epoch for train_loader 2: 299/300
# Loss for client: 2 :0.07280806132725307
# Loss C2: 0.07280806132725307
# local epoch for train_loader 4: 299/300
# Loss for client: 4 :0.7020897150039673
# Loss C4: 0.7020897150039673
# train_loss: 0.3561
# ----------
# local epoch 300/300
# local epoch for train_loader 1: 300/300
# Loss for client: 1 :0.297696728259325
# Loss C1: 0.297696728259325
# local epoch for train_loader 2: 300/300
# Loss for client: 2 :0.07104371842883882
# Loss C2: 0.07104371842883882
# local epoch for train_loader 4: 300/300
# Loss for client: 4 :0.7042171239852906
# Loss C4: 0.7042171239852906
# train_loss: 0.3577
# current epoch: 300 current mean dice: 0.1615 best mean dice: 0.5056 at epoch 76

# %%
checkpoint = torch.load('/home/otarola/miccai22/fedem/'+modality+'_beta_'+str(beta)+'_'+weighting_scheme+'_best_metric_model_segmentation2d_array.pth')
global_model.load_state_dict(checkpoint)
outputs = global_model(inputs)
print(modality)

count_volume = 0
dice_metric.reset()
metric_values_test = []
for test_data in all_test_loader:
    count_volume = count_volume+1
    cur_image, cur_label = test_data
    cur_outputs = []
    cur_labels  = []
    labels   = torch.tensor(cur_label).to(device)
    for ct_slice in range(cur_image.shape[-1]):
        cur_ct_slice = torch.tensor(cur_image[:,:,:,:,ct_slice]).to(device)        
        label    = labels[:,:,:,:,ct_slice]
        outputs = global_model(cur_ct_slice)

        cur_outputs.append(outputs.cpu().detach().numpy()>0.5)
        cur_labels.append(label.cpu().detach().numpy()>0.5)
    #print(torch.tensor(cur_outputs[-1]).shape)
    #print(torch.tensor(cur_labels[-1]).shape)
        dice_metric(y_pred=torch.tensor(cur_outputs[-1]), y=torch.tensor(cur_labels[-1]))

    # aggregate the final mean dice result
    metric = dice_metric.aggregate().item()
    dice_metric.reset()
    metric_values_test.append(metric)
print("AVG TEST DICE SCORE FOR LEARNING RATE "+str(learning_rate) + ": " + str(np.mean(metric_values_test)) + " - STD: " + str(np.std(metric_values_test)))
print(metric_values_test)
# Out:
# Tmax
# /tmp/ipykernel_629951/3251012581.py:14: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   labels   = torch.tensor(cur_label).to(device)
# /tmp/ipykernel_629951/3251012581.py:16: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   cur_ct_slice = torch.tensor(cur_image[:,:,:,:,ct_slice]).to(device)
# AVG TEST DICE SCORE FOR LEARNING RATE 0.000932: 0.35972078268726665 - STD: 0.3079528126439487
# [0.07033639401197433, 0.4547461271286011, 0.0, 0.04846785590052605, 0.8387826681137085, 0.8354261517524719, 0.24476110935211182, 0.8222819566726685, 0.36120402812957764, 0.8022418022155762, 0.33318814635276794, 0.11142061650753021, 0.2721012532711029, 0.0, 0.200853630900383]
